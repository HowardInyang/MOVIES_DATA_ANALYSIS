# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
print("current working directory:", os.getcwd())
from sklearn.preprocessing import MinMaxScaler
# Out:
# current working directory: C:\Users\USER

# %%
# First, install the required dependency
# !pip install xlrd>=2.0.1

# Then import pandas and read the Excel file
import pandas as pd
df = pd.read_excel("movies.xls")
df.head()
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0          1.33   385907.0             NaN  ...                      436
# 1          1.33   100000.0       3000000.0  ...                        2
# 2          1.33   245000.0             NaN  ...                       81
# 3          1.33  6000000.0         26435.0  ...                      136
# 4          1.33        NaN          9950.0  ...                      426
#
#   Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                       22                      9.0
# 1                        2                      0.0
# 2                       12                      6.0
# 3                       23                     18.0
# 4                       20                      3.0
#
#   Facebook Likes - cast Total  Facebook likes - Movie  Facenumber in posters  \
# 0                         481                     691                      1
# 1                           4                       0                      1
# 2                         108                     226                      0
# 3                         203                   12000                      1
# 4                         455                     926                      1
#
#    User Votes  Reviews by Users  Reviews by Crtiics  IMDB Score
# 0       10718                88                69.0         8.0
# 1           5                 1                 1.0         4.8
# 2        4849                45                48.0         8.3
# 3      111841               413               260.0         8.3
# 4        7431                84                71.0         8.0
#
# [5 rows x 25 columns]

# %%
df.describe()
# Out:
#               Year     Duration  Aspect Ratio        Budget  Gross Earnings  \
# count  1338.000000  1338.000000   1308.000000  1.281000e+03    1.086000e+03
# mean   1987.289985   113.071001      1.987752  2.712064e+07    4.752741e+07
# std      14.124870    27.434048      0.310047  8.466937e+07    6.113161e+07
# min    1916.000000    25.000000      1.180000  7.000000e+03    5.494000e+03
# 25%    1982.000000    96.000000      1.850000  4.000000e+06    8.182800e+06
# 50%    1993.000000   107.000000      1.850000  1.400000e+07    2.724075e+07
# 75%    1997.000000   123.000000      2.350000  3.300000e+07    6.358500e+07
# max    1999.000000   330.000000      2.760000  2.400000e+09    6.586723e+08
#
#        Facebook Likes - Director  Facebook Likes - Actor 1  \
# count                1338.000000               1338.000000
# mean                 1026.567265               5255.186846
# std                  3446.329257               8652.096738
# min                     0.000000                  0.000000
# 25%                     6.000000                605.000000
# 50%                    56.500000                925.500000
# 75%                   272.000000              10000.000000
# max                 21000.000000              49000.000000
#
#        Facebook Likes - Actor 2  Facebook Likes - Actor 3  \
# count               1338.000000               1336.000000
# mean                1227.041106                456.738772
# std                 2891.932284                880.031542
# min                    0.000000                  0.000000
# 25%                  273.000000                136.000000
# 50%                  559.000000                324.000000
# 75%                  849.000000                586.500000
# max                29000.000000              13000.000000
#
#        Facebook Likes - cast Total  Facebook likes - Movie  \
# count                  1338.000000             1338.000000
# mean                   7673.354260             2656.870703
# std                   11055.985788             7446.142461
# min                       0.000000                0.000000
# 25%                    1412.000000                0.000000
# 50%                    2660.000000               17.500000
# 75%                   11937.750000              812.000000
# max                   74382.000000           108000.000000
#
#        Facenumber in posters    User Votes  Reviews by Users  \
# count            1338.000000  1.338000e+03       1338.000000
# mean                1.167414  8.538817e+04        255.183857
# std                 1.608806  1.560198e+05        343.287920
# min                 0.000000  5.000000e+00          1.000000
# 25%                 0.000000  9.905500e+03         77.250000
# 50%                 1.000000  3.370500e+04        159.000000
# 75%                 2.000000  9.031425e+04        306.750000
# max                15.000000  1.689764e+06       4144.000000
#
#        Reviews by Crtiics   IMDB Score
# count         1335.000000  1338.000000
# mean            85.108614     6.702167
# std             62.040982     1.066497
# min              1.000000     2.300000
# 25%             39.000000     6.100000
# 50%             71.000000     6.800000
# 75%            118.000000     7.400000
# max            392.000000     9.300000

# %%
df.isnull().sum()
# Out:
# Title                            0
# Year                             0
# Genres                           0
# Language                         5
# Country                          0
# Content Rating                  22
# Duration                         0
# Aspect Ratio                    30
# Budget                          57
# Gross Earnings                 252
# Director                         0
# Actor 1                          0
# Actor 2                          0
# Actor 3                          2
# Facebook Likes - Director        0
# Facebook Likes - Actor 1         0
# Facebook Likes - Actor 2         0
# Facebook Likes - Actor 3         2
# Facebook Likes - cast Total      0
# Facebook likes - Movie           0
# Facenumber in posters            0
# User Votes                       0
# Reviews by Users                 0
# Reviews by Crtiics               3
# IMDB Score                       0
# dtype: int64

# %%
df.isnull().mean() * 100
# Out:
# Title                           0.000000
# Year                            0.000000
# Genres                          0.000000
# Language                        0.373692
# Country                         0.000000
# Content Rating                  1.644245
# Duration                        0.000000
# Aspect Ratio                    2.242152
# Budget                          4.260090
# Gross Earnings                 18.834081
# Director                        0.000000
# Actor 1                         0.000000
# Actor 2                         0.000000
# Actor 3                         0.149477
# Facebook Likes - Director       0.000000
# Facebook Likes - Actor 1        0.000000
# Facebook Likes - Actor 2        0.000000
# Facebook Likes - Actor 3        0.149477
# Facebook Likes - cast Total     0.000000
# Facebook likes - Movie          0.000000
# Facenumber in posters           0.000000
# User Votes                      0.000000
# Reviews by Users                0.000000
# Reviews by Crtiics              0.224215
# IMDB Score                      0.000000
# dtype: float64

# %%
df.isnull().sum() / len(df) * 100
# Out:
# Title                           0.000000
# Year                            0.000000
# Genres                          0.000000
# Language                        0.373692
# Country                         0.000000
# Content Rating                  1.644245
# Duration                        0.000000
# Aspect Ratio                    2.242152
# Budget                          4.260090
# Gross Earnings                 18.834081
# Director                        0.000000
# Actor 1                         0.000000
# Actor 2                         0.000000
# Actor 3                         0.149477
# Facebook Likes - Director       0.000000
# Facebook Likes - Actor 1        0.000000
# Facebook Likes - Actor 2        0.000000
# Facebook Likes - Actor 3        0.149477
# Facebook Likes - cast Total     0.000000
# Facebook likes - Movie          0.000000
# Facenumber in posters           0.000000
# User Votes                      0.000000
# Reviews by Users                0.000000
# Reviews by Crtiics              0.224215
# IMDB Score                      0.000000
# dtype: float64

# %%
df = df.fillna(0)

# %%
df.head()
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War        0      USA      Not Rated       123
# 1          Crime|Drama        0      USA              0       110
# 2    Drama|Romance|War        0      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0          1.33   385907.0             0.0  ...                      436
# 1          1.33   100000.0       3000000.0  ...                        2
# 2          1.33   245000.0             0.0  ...                       81
# 3          1.33  6000000.0         26435.0  ...                      136
# 4          1.33        0.0          9950.0  ...                      426
#
#   Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                       22                      9.0
# 1                        2                      0.0
# 2                       12                      6.0
# 3                       23                     18.0
# 4                       20                      3.0
#
#   Facebook Likes - cast Total  Facebook likes - Movie  Facenumber in posters  \
# 0                         481                     691                      1
# 1                           4                       0                      1
# 2                         108                     226                      0
# 3                         203                   12000                      1
# 4                         455                     926                      1
#
#    User Votes  Reviews by Users  Reviews by Crtiics  IMDB Score
# 0       10718                88                69.0         8.0
# 1           5                 1                 1.0         4.8
# 2        4849                45                48.0         8.3
# 3      111841               413               260.0         8.3
# 4        7431                84                71.0         8.0
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (1338, 25)

# %%
df.dtypes
# Out:
# Title                           object
# Year                             int64
# Genres                          object
# Language                        object
# Country                         object
# Content Rating                  object
# Duration                         int64
# Aspect Ratio                   float64
# Budget                         float64
# Gross Earnings                 float64
# Director                        object
# Actor 1                         object
# Actor 2                         object
# Actor 3                         object
# Facebook Likes - Director        int64
# Facebook Likes - Actor 1         int64
# Facebook Likes - Actor 2         int64
# Facebook Likes - Actor 3       float64
# Facebook Likes - cast Total      int64
# Facebook likes - Movie           int64
# Facenumber in posters            int64
# User Votes                       int64
# Reviews by Users                 int64
# Reviews by Crtiics             float64
# IMDB Score                     float64
# dtype: object

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Title', 'Year', 'Genres', 'Language', 'Country', 'Content Rating',
#        'Duration', 'Aspect Ratio', 'Budget', 'Gross Earnings', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3', 'Facebook Likes - Director',
#        'Facebook Likes - Actor 1', 'Facebook Likes - Actor 2',
#        'Facebook Likes - Actor 3', 'Facebook Likes - cast Total',
#        'Facebook likes - Movie', 'Facenumber in posters', 'User Votes',
#        'Reviews by Users', 'Reviews by Crtiics', 'IMDB Score'],
#       dtype='object')

# %%
df['Genres'].value_counts()
df['Language'].value_counts()
# Out:
# Language
# English       1279
# French          11
# German           6
# Japanese         6
# 0                5
# Italian          5
# Spanish          3
# Danish           2
# Portuguese       2
# Cantonese        2
# Dutch            2
# Swedish          1
# Russian          1
# Persian          1
# Hindi            1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.boxplot(y=df['Gross Earnings'])
plt.title('Boxplot of Movies Gross Earnings')
plt.show()
